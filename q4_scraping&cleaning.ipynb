# %%
# import statements
import requests
import re
import json
import time
from bs4 import BeautifulSoup as BS

# %%
def scrape(url):
    # need header to scrape from wikipedia
    headers = {
        'User-Agent': 'SchoolProjectBot/1.0 (r1043412@student.thomasmore.be) Python-Requests/2.31.0'
    }
    page = requests.get(url, headers=headers)
    
    time.sleep(2)
    
    return BS(page.text, "html")

# %%
def get_rider_year(url):
    soup = scrape(url)

    rider_year = [
        {'rider':row.find('div', class_='riderCont').get_text(strip=True),
          'year': row.find('div', class_='year').get_text(strip=True),
          'link': row.find('div', class_='riderCont').find('a')['href']}

        for row in soup.find('ul', class_='palmares').select('li')[1:-2]
    ]

    return rider_year

# %%
def add_birthyears(dict):
    for rider in dict:
        soup = scrape('https://www.procyclingstats.com/' + rider['link'])

        # debug
        # print(soup.find('div', class_='borderbox left w65'))

        rider.update({'birthyear': soup.find('div', class_='borderbox left w65').find_all('ul', class_='list')[1].select('div')[3].get_text(strip=True)})

        return dict

# %%
def write_json(dict):
    with open(f'data/ages.json', 'r+') as file:
        # load the entire json file into memory
        file_json = json.load(file)

        # update the json with the python dictionary
        file_json['victors'].append(dict)

        # put cursor at beginning of file and overwrite it with the dictionary in memory
        file.seek(0)
        json.dump(file_json, file, indent=4)

# %%
rider_dict = get_rider_year('https://www.procyclingstats.com/race.php?race=1049&p=results&s=palmares&gctype=4&filter=Filter')
add_birthyears(rider_dict)

# debug 
print(rider_dict)

write_json(rider_dict)
# Out:
# [{'rider': '1POGAČAR Tadej', 'year': '2025', 'link': 'rider/tadej-pogacar', 'birthyear': '1998'}, {'rider': '1POGAČAR Tadej', 'year': '2024', 'link': 'rider/tadej-pogacar'}, {'rider': '1VINGEGAARD Jonas', 'year': '2023', 'link': 'rider/jonas-vingegaard'}, {'rider': '1VINGEGAARD Jonas', 'year': '2022', 'link': 'rider/jonas-vingegaard'}, {'rider': '1POGAČAR Tadej', 'year': '2021', 'link': 'rider/tadej-pogacar'}, {'rider': '1POGAČAR Tadej', 'year': '2020', 'link': 'rider/tadej-pogacar'}, {'rider': '1BERNAL Egan', 'year': '2019', 'link': 'rider/egan-bernal'}, {'rider': '1THOMAS Geraint', 'year': '2018', 'link': 'rider/geraint-thomas'}, {'rider': '1FROOME Chris', 'year': '2017', 'link': 'rider/christopher-froome'}, {'rider': '1FROOME Chris', 'year': '2016', 'link': 'rider/christopher-froome'}, {'rider': '1FROOME Chris', 'year': '2015', 'link': 'rider/christopher-froome'}, {'rider': '1NIBALI Vincenzo', 'year': '2014', 'link': 'rider/vincenzo-nibali'}, {'rider': '1FROOME Chris', 'year': '2013', 'link': 'rider/christopher-froome'}, {'rider': '1WIGGINS Bradley', 'year': '2012', 'link': 'rider/bradley-wiggins'}, {'rider': '1EVANS Cadel', 'year': '2011', 'link': 'rider/cadel-evans'}, {'rider': '1SCHLECK AndyCONTADOR Alberto', 'year': '2010', 'link': 'rider/andy-schleck'}, {'rider': '1CONTADOR Alberto', 'year': '2009', 'link': 'rider/alberto-contador'}, {'r